# %%
import math
import matplotlib.pyplot as plt

# Define the corner points and the center point
coord= [[26.489615862137086, 38.747416612793046], [26.599015190079058, 38.87793652312361], [26.661650771096472, 38.96092373230329], [26.580082889029562, 39.079206648529734], [26.591179740594068, 39.19909407048759], [26.493445464846793, 39.235210328757596], [26.39387118017632, 39.33754837447756], [26.28442659875804, 39.28695825729476], [26.37360000000001, 39.03159999999999], [26.20148904124937, 39.14919203515566], [26.093248838873503, 39.06124276375984], [26.125017115727566, 38.958435973727426], [26.173759445867606, 38.801133630937144], [26.32242674274649, 38.759052453646056], [26.32242674274649, 38.759052453646056], [26.32242674274649, 38.759052453646056], [26.32242674274649, 38.759052453646056], [26.32242674274649, 38.759052453646056], [26.32242674274649, 38.759052453646056]]
centre= [26.40315094579818, 39.00800007946735]






coord_new=coord
for i in range(len(coord)):
    if coord[i][0] <0:
        coord_new[i][0] = coord[i][0]+360
    else:
        coord_new[i][0] = coord[i][0]

if centre[0]<0:
    centre[0] = centre[0]+360

coord=coord_new

# Extract the x and y coordinates from coord
x1 = [c[0] for c in coord]
y1 = [c[1] for c in coord]
x1.append(x1[0])
y1.append(y1[0])

# Calculate the angles between the corners and the center point
angles = []
for corner in coord:
    # Calculate the difference in latitude and longitude between the corner and the center
    dlat = corner[0] - centre[0]
    dlon = corner[1] - centre[1]

    # Calculate the angle in radians between the positive x-axis and the corner point
    angle = math.atan2(dlat, dlon)

    # Append the angle to the list of angles
    angles.append(angle)

# Plot the polygon
fig, ax = plt.subplots(figsize=(10, 7)) # adjust the figsize as needed
ax.plot([c[0] for c in coord], [c[1] for c in coord], 'r-', label='Polygon')

# Add the angles to the plot
for i, corner in enumerate(coord):
    # Calculate the position for the angle label
    angle_pos = ((corner[0] + centre[0])/2, (corner[1] + centre[1])/2)
    label_offset = -0.05 # adjust this value to move the label closer or farther away

    # Calculate the unit vector from the center to the corner
    vec_x = corner[0] - centre[0]
    vec_y = corner[1] - centre[1]
    vec_mag = math.sqrt(vec_x**2 + vec_y**2)
    unit_vec_x = vec_x / vec_mag
    unit_vec_y = vec_y / vec_mag

    # Multiply the unit vector by the label offset
    label_x = corner[0] - label_offset * unit_vec_x
    label_y = corner[1] - label_offset * unit_vec_y

    # Convert the angle to degrees and format it as a string
    angle_degrees = math.degrees(angles[i])
    angle_str = '{:.2f}'.format(angle_degrees)

    # Add the angle label to the plot
    ax.text(label_x, label_y, 'N:'+str(i+1)+' A:'+angle_str, ha='center', va='center', color='blue')
    
ax.plot(x1, y1, '-ro', label='Corners')
ax.plot(centre[0], centre[1], 'bo', label='Node Center')

# Set the x and y limits based on the coordinates
ax.set_xlim(min(x1)-.1, max(x1)+.1)
ax.set_ylim(min(y1)-.1, max(y1)+.1)

# Add a legend and show the plot
ax.legend()
plt.show()

# %%
len(coord)
# Out:
# 19

# %%
import math
import matplotlib.pyplot as plt

# Define the corner points and the center point
coord= [[24.859575769968878, 31.584424802783847], [24.96941983765004, 31.68649674956228], [24.932418698723744, 31.784580743228794], [24.87442117297805, 31.920738362765388], [24.71729526408648, 31.935831426465313], [24.556403750791596, 31.901464907864874], [24.45534021681525, 31.755706953543502], [24.676000000000002, 31.678600000000007], [24.676000000000002, 31.678600000000007], [24.676000000000002, 31.678600000000007], [24.676000000000002, 31.678600000000007], [24.676000000000002, 31.678600000000007], [24.676000000000002, 31.678600000000007], [24.676000000000002, 31.678600000000007], [24.676000000000002, 31.678600000000007], [24.676000000000002, 31.678600000000007], [24.676000000000002, 31.678600000000007], [24.676000000000002, 31.678600000000007], [24.676000000000002, 31.678600000000007]]
centre= [24.709215396384536, 31.80452429258079]









coord_new=coord
for i in range(len(coord)):
    if coord[i][0] <0:
        coord_new[i][0] = coord[i][0]+360
    else:
        coord_new[i][0] = coord[i][0]

if centre[0]<0:
    centre[0] = centre[0]+360

coord=coord_new

# Extract the x and y coordinates from coord
x1 = [c[0] for c in coord]
y1 = [c[1] for c in coord]
x1.append(x1[0])
y1.append(y1[0])

# Calculate the angles between the corners and the center point
angles = []
for corner in coord:
    # Calculate the difference in latitude and longitude between the corner and the center
    dlat = corner[0] - centre[0]
    dlon = corner[1] - centre[1]

    # Calculate the angle in radians between the positive x-axis and the corner point
    angle = math.atan2(dlat, dlon)

    # Append the angle to the list of angles
    angles.append(angle)

# Plot the polygon
fig, ax = plt.subplots(figsize=(10, 7)) # adjust the figsize as needed
ax.plot([c[0] for c in coord], [c[1] for c in coord], 'r-', label='Polygon')

# Add the angles to the plot
for i, corner in enumerate(coord):
    # Calculate the position for the angle label
    angle_pos = ((corner[0] + centre[0])/2, (corner[1] + centre[1])/2)
    label_offset = -0.05 # adjust this value to move the label closer or farther away

    # Calculate the unit vector from the center to the corner
    vec_x = corner[0] - centre[0]
    vec_y = corner[1] - centre[1]
    vec_mag = math.sqrt(vec_x**2 + vec_y**2)
    unit_vec_x = vec_x / vec_mag
    unit_vec_y = vec_y / vec_mag

    # Multiply the unit vector by the label offset
    label_x = corner[0] - label_offset * unit_vec_x
    label_y = corner[1] - label_offset * unit_vec_y

    # Convert the angle to degrees and format it as a string
    angle_degrees = math.degrees(angles[i])
    angle_str = '{:.2f}'.format(angle_degrees)

    # Add the angle label to the plot
    ax.text(label_x, label_y, 'N:'+str(i+1)+' A:'+angle_str, ha='center', va='center', color='blue')
    
ax.plot(x1, y1, '-ro', label='Corners')
ax.plot(centre[0], centre[1], 'bo', label='Node Center')

# Set the x and y limits based on the coordinates
ax.set_xlim(min(x1)-.1, max(x1)+.1)
ax.set_ylim(min(y1)-.1, max(y1)+.1)

# Add a legend and show the plot
ax.legend()
plt.show()

# %%
# 16:  coast ocean         120   180.163290244505        359.892176236128                2  -1078.58585428009                6
pos_values=[179.998500383538,        179.893675852589]
neg_values=[-179.645493172570,       -179.681888661567,       -179.947000000000,       -179.626519724137,       -179.869580209755,       -179.815372512059]

# %%
# 72:  coast ocean         727   180.042731166990        359.678822072526                2  -719.422435070583                4
pos_values=[179.876963207042,        179.801858865484]
neg_values=[-179.794041670877,       -179.958400000000,       -179.965928229809,       -179.704065169898]

# %%
# 74:  coast ocean         887   179.882175203944        719.199854151084                4  -359.906802927423                2
pos_values=[179.903030552065,        179.717040418126,        179.773771874845,        179.806011306048]
neg_values=[-179.991800000000,       -179.915002927423]

# %%
sum_pos = sum(pos_values)
sum_neg = sum(neg_values)

# %%
print(sum_pos,sum_neg)
# Out:
# 359.67882207252603 -719.422435070584

# %%
if ((-sum_pos+180*len(pos_values))) >= (sum_neg+180*len(neg_values)):
    print('A')
    this_x_coord = (sum(pos_values) + sum(neg_values) + 360*len(neg_values)) / (len(pos_values) + len(neg_values))
else:
    print('B')
    this_x_coord = (sum(pos_values) - 360*len(pos_values) + sum(neg_values)) / (len(pos_values) + len(neg_values))
# Out:
# B

# %%
this_x_coord
# Out:
# -179.83670975549512

# %%
((-sum_pos+180*len(pos_values))*1)
# Out:
# 0.10782376387300019

# %%
((sum_neg+180*len(neg_values))*1)
# Out:
# 1.414145719912085

# %%
((-sum_pos+180*len(pos_values))*len(pos_values))
# Out:
# 0.21564752774600038

# %%
((sum_neg+180*len(neg_values))*len(pos_values))
# Out:
# 2.82829143982417

# %%
sum_neg+180*len(neg_values)
# Out:
# 0.5775649294159848

# %%
if sum_pos-360*len(sum_pos) >= -sum_neg:
